# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
import os

import requests
import json

# %%
def get_data(ticker, per, data_type):
    output = pd.read_csv(f"data/{ticker}_{per}_{data_type}.csv", index_col="Date", parse_dates=True)
    return output

# %%
data = get_data("MSFT", "1y", "Close")
data.plot(kind="line", figsize=(8, 8), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>], dtype=object)
